# %%
from utils.plot_utils import read_auto_labels_and_gold_labels
from utils.plot_utils import extract_labels
from utils.plot_utils import cm_analysis_plot
from utils.plot_utils import no_fact_to_off_topic

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
def calculate_metrics(y_true, y_pred, labels):
    
    f1 = f1_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")
    accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    precision = precision_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")
    recall = recall_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")

    print(f"F1 Score: {f1}, Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}")
    return

# %%
gold_path = "../../gpt-neo/gen_outputs/labeled_samples/joined_labels.jsonl"
test_gold_path = "../../gpt-neo/gen_outputs/labeled_samples/labeled_test-set-gen.jsonl"
labels = ["true", "false", "not_enough_evidence", "off_topic", "no_fact"]

# %% [markdown]
# # Vanilla Evaluation

# %% [markdown]
# ## Vanilla, hence with out add_ne

# %%
auto_path = "../../../eval_archive/vanilla/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/vanilla_train.png", labels=labels)
# Out:
# F1 Score: 0.447343879135494, Accuracy: 0.4084507042253521, Precision: 0.6823954696854045, Recall: 0.40883458646616544

# %%
auto_path = "../../../eval_archive/vanilla/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/vanilla_test.png", labels=labels)
# Out:
# F1 Score: 0.4019246742398056, Accuracy: 0.3888888888888889, Precision: 0.6328717926836206, Recall: 0.3888888888888889

# %% [markdown]
# ## Combined K=1; Max entail

# %% [markdown]
# ## MNLI-Large

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k1/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-combined-k1-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.4680545849126842, Accuracy: 0.4253521126760563, Precision: 0.70078685961108, Recall: 0.4257518796992481

# %%
auto_path = "../../../eval_archive/vanilla/with_add_nes/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/delete_me.png", labels=labels)
# Out:
# F1 Score: 0.45900692222765066, Accuracy: 0.4187793427230047, Precision: 0.6858282451289895, Recall: 0.4191729323308271

# %%
auto_path = "../../../eval_archive/vanilla/with_add_nes/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/vanilla_test_add_nes.png", labels=labels)
# Out:
# F1 Score: 0.37728312337651215, Accuracy: 0.37222222222222223, Precision: 0.6617248058417649, Recall: 0.37222222222222223

# %% [markdown]
# ### Vitaminc-MNLI

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k1/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-combined-k1-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.39629113676803646, Accuracy: 0.37370892018779345, Precision: 0.6526681617045947, Recall: 0.37406015037593987

# %% [markdown]
# ### K=4

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k4/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-combined-k4-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.48537162904887055, Accuracy: 0.447887323943662, Precision: 0.7109738936439307, Recall: 0.4483082706766917

# %%
# test set
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k4/test-set/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/test-set-Large-MNLI-combined-k4-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.37522232596742394, Accuracy: 0.37777777777777777, Precision: 0.6521736918476049, Recall: 0.37777777777777777

# %%
# SANITY WITH HUG
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k4/hug_mnli_large_sanity.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.48704793806821683, Accuracy: 0.4497652582159624, Precision: 0.7104168641224897, Recall: 0.450187969924812

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k4/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.5716315354629687, Accuracy: 0.5596244131455399, Precision: 0.6247551531175899, Recall: 0.5601503759398496

# %%
# SANITY CHECK
auto_path = "../../../eval_archive/after_fix/combined/max_entail/k4/sanity_vitaminc-mnli.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-combined-k4-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.3699624334840306, Accuracy: 0.36619718309859156, Precision: 0.6010177143288721, Recall: 0.36654135338345867

# %% [markdown]
# ## Embedding Sim

# %% [markdown]
# ### k=2

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_entail/k2/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-k2-max_entail", labels=labels)
# Out:
# F1 Score: 0.4771206626181053, Accuracy: 0.43380281690140843, Precision: 0.70087520077002, Recall: 0.4342105263157895

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_entail/k2/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-emb_sim-k2-max_entail", labels=labels)
# Out:
# F1 Score: 0.37977470657191936, Accuracy: 0.3615023474178404, Precision: 0.661948614564901, Recall: 0.3618421052631579

# %% [markdown]
# ### k=8

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_entail/k8/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-k8-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.47415208922312857, Accuracy: 0.4356807511737089, Precision: 0.6990070757500338, Recall: 0.43609022556390975

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_entail/k8/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-emb_sim-k8-max_entail.png", labels=labels)
# Out:
# F1 Score: 0.3708074912034651, Accuracy: 0.3643192488262911, Precision: 0.6473543746291868, Recall: 0.36466165413533835

# %% [markdown]
# ## Max True_False

# %% [markdown]
# ### Combine

# %% [markdown]
# #### k1

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_true_false/k1/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-combined-k1-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5049558134283998, Accuracy: 0.4629107981220657, Precision: 0.6704876305005623, Recall: 0.4633458646616541

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_true_false/k1/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-combined-k1-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.44443089494553584, Accuracy: 0.40938967136150234, Precision: 0.63235305923539, Recall: 0.40977443609022557

# %% [markdown]
# ### K=4

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_true_false/k4/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-combined-k4-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5746979988201166, Accuracy: 0.5530516431924882, Precision: 0.662351447747686, Recall: 0.5535714285714286

# %%
# Test set
auto_path = "../../../eval_archive/after_fix/combined/max_true_false/k4/test-set/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/test-set-Large-MNLI-combined-k4-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.555279090044213, Accuracy: 0.55, Precision: 0.6039421338155515, Recall: 0.55

# %%
auto_path = "../../../eval_archive/after_fix/combined/max_true_false/k4/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-combined-k4-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.47885770354564283, Accuracy: 0.4460093896713615, Precision: 0.6109074520422244, Recall: 0.44642857142857145

# %% [markdown]
# ### Embedding Similarity

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k2/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-k2-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.49919741092469555, Accuracy: 0.45539906103286387, Precision: 0.6857133713109402, Recall: 0.4558270676691729

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k2/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-emb_sim-k2-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.44440442681356457, Accuracy: 0.4056338028169014, Precision: 0.6626070113412484, Recall: 0.40601503759398494

# %% [markdown]
# ### k=8

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/additonal_nes_label.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-k8-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5831298705880048, Accuracy: 0.5568075117370892, Precision: 0.6708561330414621, Recall: 0.5573308270676691

# %%
# Addtional ne - new imp
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/addtitional_ne/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.5839877295723169, Accuracy: 0.5586854460093896, Precision: 0.6674230584355775, Recall: 0.5592105263157895

# %% [markdown]
# ## Test-Set

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/test-set/addtional_nes/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/test-set-Large-MNLI-emb_sim-k8-max_true_false.png.png", labels=labels)
# Out:
# F1 Score: 0.59026377657152, Accuracy: 0.5833333333333334, Precision: 0.6393834828617437, Recall: 0.5833333333333334

# %%
## Test set without additonal nes
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/test-set/labeled_test-set-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, test_gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/test-set-wo_add_nes-Large-MNLI-emb_sim-k8-max_true_false", labels=labels)
# Out:
# F1 Score: 0.5555391965753163, Accuracy: 0.5444444444444444, Precision: 0.6152222222222221, Recall: 0.5444444444444444

# %%
# Addtional ne - new imp
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/addtitional_ne/new.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/wo_add_nes-Large-MNLI-emb_sim-k8-max_true_false", labels=labels)
# Out:
# F1 Score: 0.5602238114691591, Accuracy: 0.532394366197183, Precision: 0.659067288431339, Recall: 0.5328947368421053

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.5842843846734292, Accuracy: 0.5577464788732395, Precision: 0.6687528728679798, Recall: 0.5582706766917294

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/large_mnli_big_model.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-big_model-k8-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5750762061249073, Accuracy: 0.5474178403755868, Precision: 0.6630042419226067, Recall: 0.5479323308270677

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/large_mnli_big_model_dot_sim.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-big_model-dot_sim-k8-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5798633752457225, Accuracy: 0.5511737089201878, Precision: 0.6695390022869261, Recall: 0.5516917293233082

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/large_mnli_qa_model_dot_sim.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/Large-MNLI-emb_sim-qa_model-dot_sim-k8-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.5711235160364468, Accuracy: 0.5492957746478874, Precision: 0.6562317189896445, Recall: 0.549812030075188

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.4995848134364376, Accuracy: 0.4619718309859155, Precision: 0.6262268586377246, Recall: 0.462406015037594

# %%
auto_path = "../../../eval_archive/after_fix/emb_sim/max_true_false/k8/150_labeled-gen_vitaminc-fever_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./plots/VitaminC-MNLI-emb_sim-k=8-max_true_false.png", labels=labels)
# Out:
# F1 Score: 0.3996466080879058, Accuracy: 0.37183098591549296, Precision: 0.5894181290048025, Recall: 0.37218045112781956
