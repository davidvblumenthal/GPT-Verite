# %%
from utils.plot_utils import read_auto_labels_and_gold_labels
from utils.plot_utils import extract_labels
from utils.plot_utils import cm_analysis_plot
from utils.plot_utils import no_fact_to_off_topic

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
def calculate_metrics(y_true, y_pred, labels):
    
    f1 = f1_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")
    accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    precision = precision_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")
    recall = recall_score(y_true=y_true, y_pred=y_pred, labels=labels, average="weighted")

    print(f"F1 Score: {f1}, Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}")
    return

# %%
auto_path = "./automatic_labels.jsonl"
gold_path = "../../gpt-neo/gen_outputs/labeled_samples/joined_labels.jsonl"

# %% [markdown]
# # Vanilla Evaluation

# %%
auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

# %%
count = 0
for gold, auto in zip(gold_gen, auto_gen):
    len_gold = len(gold["single_sentences"])
    len_auto = len(auto["single_sentences"])

    if len_gold != len_auto:
        print(count)

    count += 1
# Out:
# 67

# %%
labels = ["true", "false", "not_enough_evidence", "off_topic", "no_fact"]
#labels = ["true", "false", "off_topic", "no_fact"]
#sample_weight = [1, 1, 0.5, 1, 1]
#f1 = f1_score(y_true=labels_gold, y_pred=labels_auto, labels=labels, average="weighted") # , sample_weight=sample_weight
#f1

# %%
cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./cm.png", labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-25dcee7e8524> in <module>
# ----> 1 cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./cm.png", labels=labels)
#
# NameError: name 'labels_gold' is not defined

# %%
new_gold, new_auto = no_fact_to_off_topic(labels_gold, labels_auto)

new_labels = ["true", "false", "not_enough_evidence", "off_topic"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-31344abf88e2> in <module>
# ----> 1 new_gold, new_auto = no_fact_to_off_topic(labels_gold, labels_auto)
#       2
#       3 new_labels = ["true", "false", "not_enough_evidence", "off_topic"]
#
# NameError: name 'labels_gold' is not defined

# %%
cm_analysis_plot(y_true=new_gold , y_pred=new_auto, filename="./cm_off_topic.png", labels=new_labels)

# %% [markdown]
# # Labels with changed code

# %%
auto_path = "../../gpt-neo/gen_outputs/labeled_samples/150_labeled-gen_new_impl_results_labels.jsonl"   
gold_path = "../../gpt-neo/gen_outputs/labeled_samples/150_labeled-gen.jsonl"

# %%
auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

# %%
cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./cm.png", labels=labels)

# %% [markdown]
# # Dev_save_evidence implementation - Large mnli k=1

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=1/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.5072054684257938, Accuracy: 0.47699530516431926, Precision: 0.6008261583235296, Recall: 0.4774436090225564

# %% [markdown]
# # Dev_save_evidence implementation - Vitaminc-mnli k=1

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=1/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)
cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.39629113676803646, Accuracy: 0.37370892018779345, Precision: 0.6526681617045947, Recall: 0.37406015037593987

# %% [markdown]
# # Dev_save_evidence implementation - Vitaminc-fever k=1

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=1/150_labeled-gen_vitaminc-fever_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

# %%
labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

# %%
cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-fever_k1.png", labels=labels)

# %% [markdown]
# # Dev_save_evidence implementation - Large-mnli k=4

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=4/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_k4.png", labels=labels)
# Out:
# F1 Score: 0.5072860920809361, Accuracy: 0.476056338028169, Precision: 0.5911728384232439, Recall: 0.47650375939849626

# %% [markdown]
# ### Dev_save_evidence implementation - vitaminc-mnli k=4

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=4/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc_mnli_k4.png", labels=labels)
# Out:
# F1 Score: 0.3699624334840306, Accuracy: 0.36619718309859156, Precision: 0.6010177143288721, Recall: 0.36654135338345867

# %% [markdown]
# # Highest General

# %% [markdown]
# ## K=1

# %% [markdown]
# ### impl with_highest_general_prob - lage-mnli k=1

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_general/k=1/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./general_prob_large_mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.45357590630897676, Accuracy: 0.4291079812206573, Precision: 0.5692814302469773, Recall: 0.42951127819548873

# %% [markdown]
# ### impl with_highest_general_prob - vitaminc-mnli k=1

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_general/k=1/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./general_prob_vitaminc_mnli_k1.png", labels=labels)
# Out:
# F1 Score: 0.3794727166335756, Accuracy: 0.355868544600939, Precision: 0.6175435050732481, Recall: 0.35620300751879697

# %% [markdown]
# ## K=4

# %% [markdown]
# ### impl with_highest_general_prob - lage-mnli k=4

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_general/k=4/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./general_prob_large_mnli_k4.png", labels=labels)
# Out:
# F1 Score: 0.42574978048646556, Accuracy: 0.4291079812206573, Precision: 0.5829998691045679, Recall: 0.42951127819548873

# %% [markdown]
# ### impl with_highest_general_prob - vitaminc-mnli k=4

# %%
auto_path = "../../../eval_archive/different_entail_models/highest_general/k=4/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./general_prob_vitaminc_mnli_k4.png", labels=labels)
# Out:
# F1 Score: 0.282927435930765, Accuracy: 0.27981220657276995, Precision: 0.5727646362778566, Recall: 0.2800751879699248

# %% [markdown]
# # Coref Evaluation

# %%
auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

# %%
from utils.compare_utils import get_miss_match
from utils.compare_utils import get_miss_match_analysis
from utils.utils import write_jsonl
#auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

# %%
true_false_miss_match = get_miss_match(gold_labels=gold_gen, auto_labels=auto_gen, miss_match=("true", "false"))

# %%
pairs_gold = extract_sentence_label_pairs(gold_gen)
    
auto = extract_gt_truth_from_analysis(auto_gen)

# %%
# Best performing analysis HE-k4-Large-MNLI

auto_path = "../../../eval_archive/different_entail_models/highest_entail/k=4/150_labeled-gen_large_mnli_results_analysis.jsonl"
auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

true_false_miss_match = get_miss_match_analysis(gold_labels=gold_gen, auto_label_with_analysis=auto_gen, miss_match=("true", "false"))

save_path = "./best_performing_gold_true__auto_false_missmatch.jsonl"
write_jsonl(save_path, true_false_miss_match)

# %%
save_path = "./gold_true__auto_false__missmatch.jsonl"
write_jsonl(save_path, true_false_miss_match)

# %% [markdown]
# # Evidence Just with Embed-Sim

# %% [markdown]
# ## K=4

# %% [markdown]
# ### MNLI-Large

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k4/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-k4.png", labels=labels)
# Out:
# F1 Score: 0.5067633820291609, Accuracy: 0.476056338028169, Precision: 0.5944643132800075, Recall: 0.47650375939849626

# %% [markdown]
# ### Vitamnic-MNLI

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k4/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-k4.png", labels=labels)

# %% [markdown]
# ## K=2

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k2/150_labeled-gen_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-k2.png", labels=labels)
# Out:
# F1 Score: 0.4956454074683111, Accuracy: 0.4666666666666667, Precision: 0.594138516929457, Recall: 0.46710526315789475

# %% [markdown]
# ## K=1

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k1/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-k1.png", labels=labels)
# Out:
# F1 Score: 0.4891198342215815, Accuracy: 0.460093896713615, Precision: 0.5960933624468887, Recall: 0.4605263157894737

# %% [markdown]
# ## Just Embed-Sim with True-False max

# %% [markdown]
# ### K=8

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/emb-sim-k8-highest-true-false/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-highest-true-false-k8.png", labels=labels)

#accuracy_score(y_true=labels_gold, y_pred=labels_auto) #, average="weighted")
calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)
#f1_score(y_true=labels_gold, y_pred=labels_auto, labels=labels, average="weighted")
# Out:
# F1 Score: 0.4784486756414272, Accuracy: 0.532394366197183, Precision: 0.5983256731247598, Recall: 0.5328947368421053

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/emb-sim-k8-highest-true-false/150_labeled-gen_vitaminc-mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc-mnli_embed-sim-highest-true-false-k8.png", labels=labels)

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)
# Out:
# F1 Score: 0.4995848134364376, Accuracy: 0.4619718309859155, Precision: 0.6262268586377246, Recall: 0.462406015037594

# %% [markdown]
# ## Just embed sim with max entail prob k=8

# %% [markdown]
# ### Original Embedding Model

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k8/old_model/150_labeled-gen_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-k8.png", labels=labels)

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)
# Out:
# F1 Score: 0.5288923609754764, Accuracy: 0.5004694835680751, Precision: 0.6055561865477643, Recall: 0.5009398496240601

# %% [markdown]
# ## Same as above but with different emb model ->all-mpnet-base-v2

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k8/all-mpnet-base-v2/large_mnli_150_labeled-gen_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large_mnli_embed-sim-new_model-k8.png", labels=labels)

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)
# Out:
# F1 Score: 0.5166153321183661, Accuracy: 0.48826291079812206, Precision: 0.5924153156261838, Recall: 0.48872180451127817

# %%
auto_path = "../../../eval_archive/different_entail_models/large-mnli/evidence-emb-sim-k8/all-mpnet-base-v2/vitaminc_150_labeled-gen_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./vitaminc_embed-sim-new_model-k8.png", labels=labels)
# Out:
# F1 Score: 0.3603578603233302, Accuracy: 0.3502347417840376, Precision: 0.6174205123189783, Recall: 0.3505639097744361

# %% [markdown]
# ## Just embed sim with max entail prob k=8 Without Addtional NEs

# %%
auto_path = "/Users/davidblumenthal/Documents/Master_Thesis/Evaluation/eval_archive/different_entail_models/emb_sim_k8_wo_add_nes/150_labeled-gen_large_mnli_results_labels.jsonl"

auto_gen, gold_gen = read_auto_labels_and_gold_labels(auto_path, gold_path)

labels_gold = extract_labels(gold_gen)
labels_auto = extract_labels(auto_gen)

assert len(labels_gold) == len(labels_auto), f"Len auto: {len(labels_auto)}, Len gold: {len(labels_gold)}"

calculate_metrics(y_true=labels_gold, y_pred=labels_auto, labels=labels)

cm_analysis_plot(y_true=labels_gold , y_pred=labels_auto, filename="./large-mnli_embed-sim-wo_add_nes-k8.png", labels=labels)
# Out:
# F1 Score: 0.5131624598183328, Accuracy: 0.4835680751173709, Precision: 0.5985402311504573, Recall: 0.48402255639097747
